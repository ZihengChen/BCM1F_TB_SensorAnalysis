# %%
import pandas as pd
from pylab import *
from TBTree_PulseAmpFitter import PulseAmpFitter

# %matplotlib inline
dataDir = "../data"
# Out:
# Welcome to JupyROOT 6.16/00

# %% [markdown]
# # 0. Example Fit

# %%
run = "198"
df = pd.read_pickle(dataDir + "/TBTree/{}.pkl".format(run))
# load channel
backend, channel = "VME", 3
key = "{}Ch{}".format(backend,channel)
ch = df.query("{}_pulsePosPassCuts>0 & {}_pulseAmpPassCuts>0".format(key,key))

# fitting
fitter = PulseAmpFitter(ch[key+"_pulseAmp"],binsize=1)
fitter.fitRange(15,40, None, True)
# plot
fitter.plot()
title = "Run {}, sensor-1 300V, {}, n={}".format(run, key, len(ch))
fitter.axes[0].set_title(title, fontsize=14)
# Out:
#  FCN=4.32012 FROM MIGRAD    STATUS=CONVERGED     565 CALLS         566 TOTAL
#                      EDM=1.66787e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  LandauWidth   1.82304e+00   8.65173e-02   4.38392e-05   1.04154e-02
#    2  LandauMPV    1.99974e+01   1.39871e-01   8.34940e-05  -1.04543e-02
#    3  Normalisation   1.21092e+04   2.40541e+03   1.56541e-01  -1.07549e-05
#    4  GaussianSigma   1.61283e+00   3.34161e-01   2.24178e-05  -7.85697e-02
#                                ERR DEF= 0.5

# %%
# chplot = ch.query("{}<{}_pulseAmp<{} and nTriples==1".format(fitter.fit_xmin, key, fitter.fit_xmax))
chplot = ch.query("nTriples==1")
plt.figure(figsize=(6,3.5),facecolor='w')
x = np.array([chplot.tposX_dut]).reshape(-1)
y = np.array([chplot.tposY_dut]).reshape(-1)
xBins,yBins = np.arange(-4,3.1,0.1),np.arange(-1,3.1,0.1)
plt.hist2d(x,y,bins=(xBins,yBins),cmap="hot")
plt.xlabel("x [mm]",fontsize=14)
plt.ylabel("y [mm]",fontsize=14)
plt.axis('equal')
plt.xlim(-4,3)
plt.ylim(-1,3)
title = "Run {}, sensor-1 300V, {}, n={}".format(run, key, len(chplot))
plt.title(title, fontsize=14)

# %% [markdown]
# # 1. Fit Sensor 1

# %%
runMng = {
    "u"  :[50,100,150,200,250,300,350,400,500],               
    "run":["223","216","217","218","219","198","220","221","222"],
    "uTCACh2_fitRange":[(12,60),(20,80),(20,80),(20,80),(25,80),(25,80),(25,80),(25,80),(25,80)],
    "uTCACh3_fitRange":[(12,60),(20,80),(20,80),(20,80),(25,80),(25,80),(25,80),(25,80),(25,80)],
    "VMECh2_fitRange" :[( 6,40),(10,40),(10,40),(15,40),(15,40),(15,40),(15,40),(15,40),(15,40)],
    "VMECh3_fitRange" :[( 6,40),(10,40),(10,40),(15,40),(15,40),(15,40),(15,40),(15,40),(15,40)],
    "uTCACh2_mpv":[],"uTCACh3_mpv":[],"VMECh2_mpv":[],"VMECh3_mpv":[],
    }

for i in range(len(runMng["run"])):
    run = runMng["run"][i]
    df = pd.read_pickle(dataDir + "/TBTree/{}.pkl".format(run))
    for backend in ["uTCA","VME"]:
        for channel in "23":
            # get channe;
            key = "{}Ch{}".format(backend,channel)
            ch = df.query("{}_pulsePosPassCuts>0 & {}_pulseAmpPassCuts>0".format(key,key))
            title = "Run {}, sensor-1 {}V, {}, n={}".format(run,runMng["run"][i], key, len(ch))
            # fitting
            xmin,xmax = runMng[key+"_fitRange"][i]
            fitter = PulseAmpFitter(ch[key+"_pulseAmp"],binsize=1)
            fitter.fitRange(xmin,xmax, None, True)
            runMng[key+"_mpv"].append(fitter.param["argmax"])
            # plot
            fitter.plot()
            fitter.axes[0].set_title(title, fontsize=14)
            plt.savefig("../plots/fitPulseAmp/sensor1/run{}_{}.png".format(run,key),dpi=300)
            plt.close()
            
            # make heatmap
            chplot = ch.query("nTriples==1")
            plt.figure(figsize=(6,3.5),facecolor='w')
            x = np.array([chplot.tposX_dut]).reshape(-1)
            y = np.array([chplot.tposY_dut]).reshape(-1)
            xBins,yBins = np.arange(-4,3.1,0.1),np.arange(-1,3.1,0.1)
            plt.hist2d(x,y,bins=(xBins,yBins),cmap="hot")
            plt.xlabel("x [mm]",fontsize=14)
            plt.ylabel("y [mm]",fontsize=14)
            plt.axis('equal')
            plt.xlim(-4,3)
            plt.ylim(-1,3)
            title = "Run {}, sensor-1 {}V, {}, n={}".format(run, runMng["run"][i], key, len(chplot))
            plt.title(title, fontsize=14)
            plt.savefig("../plots/heatmap/sensor1/run{}_{}.png".format(run,key),dpi=300)
            plt.close()

pd.DataFrame(runMng).to_pickle(dataDir + "/FitPulseAmp/sensor1.pkl")
# Out:
#  FCN=11.2038 FROM MIGRAD    STATUS=CONVERGED     652 CALLS         653 TOTAL
#                      EDM=1.36162e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  LandauWidth   1.99433e+00   3.12473e-01   1.79678e-04  -4.73084e-03
#    2  LandauMPV    2.02340e+01   2.27442e-01   3.21220e-04   3.83017e-03
#    3  Normalisation   1.63433e+03   2.94335e+02   5.73331e-02  -2.10650e-06
#    4  GaussianSigma   3.80639e+00   6.92475e-01   1.52342e-04  -1.80122e-03
#                                ERR DEF= 0.5
#  FCN=11.9084 FROM MIGRAD    STATUS=CONVERGED     516 CALLS         517 TOTAL
#                      EDM=1.92433e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  LandauWidth   2.34915e+00   2.15590e-01   1.73893e-04  -1.17705e-03
#    2  LandauMPV    2.09446e+01   1.64279e-01   2.82846e-04  -7.26068e-04
#    3  Normalisation   2.33394e+03   4.06772e+02   7.93042e-02   1.04691e-06
#    4  GaussianSigma   2.96778e+00   5.09237e-01   1.11956e-04   3.95227e-04
#                                ERR DEF= 0.5
#  FCN=2.01299 FROM MIGRAD    STATUS=CONVERGED     610 CALLS         611 TOTAL
#                      EDM=1.0569e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  LandauWidth   1.23973e+00   1.62814e-01   4.00708e-05   1.07114e-02
#    2  LandauMPV    1.00616e+01   3.69138e-01   8.29296e-05   6.42597e-03
#    3  Normalisation   4.82792e+03   2.43934e+03   8.09073e-02  -3.03820e-07
#    4  GaussianSigma   1.29735e+00   7.16932e-01   2.37009e-05   3.25036e-03
#                                ERR DEF= 0.5
#  FCN=3.91118 FROM MIGRAD    STATUS=CONVERGED     534 CALLS         535 TOTAL
#                      EDM=7.86756e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  LandauWidth   1
-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  LandauWidth   2.88100e+00   2.57787e-01   7.20636e-04  -8.80138e-04
#    2  LandauMPV    4.27089e+01   1.68430e-01   1.17669e-03  -4.14711e-04
#    3  Normalisation   1.94850e+03   2.00527e+02   1.92371e-01   1.89633e-06
#    4  GaussianSigma   5.13309e+00   5.09520e-01   5.70606e-04   2.92425e-04
#                                ERR DEF= 0.5
#  FCN=14.5112 FROM MIGRAD    STATUS=CONVERGED     612 CALLS         613 TOTAL
#                      EDM=9.52293e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  LandauWidth   1.36469e+00   1.62073e-01   1.15114e-04  -4.78896e-04
#    2  LandauMPV    1.94363e+01   1.06672e-01   1.98198e-04  -1.26815e-02
#    3  Normalisation   3.55647e+03   4.57314e+02   1.14725e-01  -7.80376e-06
#    4  GaussianSigma   2.62193e+00   3.31343e-01   9.67977e-05  -1.25727e-02
#                                ERR DEF= 0.5
#  FCN=7.37244 FROM MIGRAD    STATUS=CONVERGED     450 CALLS         451 TOTAL
#                      EDM=8.53029e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  LandauWidth   1.68417e+00   1.24411e-01   7.84211e-05   4.83812e-04
#    2  LandauMPV    2.02798e+01   1.31257e-01   1.38143e-04   8.29057e-04
#    3  Normalisation   5.27400e+03   8.97719e+02   1.17484e-01   1.22291e-06
#    4  GaussianSigma   1.98823e+00   3.44815e-01   4.91255e-05   9.12215e-04
#                                ERR DEF= 0.5
#  FCN=98.6395 FROM MIGRAD    STATUS=CONVERGED     545 CALLS         546 TOTAL
#                      EDM=1.74004e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  LandauWidth   2.44394e+00   3.24693e-01   6.06297e-04   1.97786e-03
#    2  LandauMPV    3.97896e+01   1.96898e-01   1.04629e-03   6.17676e-04
#    3  Normalisation   1.40418e+03   1.45019e+02   1.19111e-01   8.12877e-07
#    4  GaussianSigma   6.05045e+00   6.00897e-01   5.81097e-04   3.34657e-03
#                                ERR DEF= 0.5
#  FCN=159.152 FROM MIGRAD    STATUS=CONVERGED     549 CALLS         550 TOTAL
#                      EDM=2.52212e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  LandauWidth   3.32727e+00   2.28640e-01   7.64310e-04  -3.32572e-03
#    2  LandauMPV    4.29671e+01   1.81615e-01   1.24604e-03  -1.71386e-03
#    3  Normalisation   2.03491e+03   2.25276e+02   2.05776e-01   1.41333e-05
#    4  GaussianSigma   4.76832e+00   5.22814e-01   5.32980e-04   4.09663e-03
#                                ERR DEF= 0.5
#  FCN=9.38974 FROM MIGRAD    STATUS=CONVERGED     469 CALLS         470 TOTAL
#                      EDM=1.19972e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  LandauWidth   1.67003e+00   1.25177e-01   9.38987e-05   1.86418e-04
#    2  LandauMPV    1.94992e+01   1.20475e-01   1.60652e-04   4.50978e-03
#    3  Normalisation   4.39765e+03   7.12556e+02   1.16346e-01   1.49934e-06
#    4  GaussianSigma   2.05858e+00   3.38479e-01   6.01934e-05   4.13372e-03
#                                ERR DEF= 0.5
#  FCN=10.9381 FROM MIGRAD    STATUS=CONVERGED     551 CALLS         552 TOTAL
#                      EDM=5.41775e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  LandauWidth   1.76083e+00   1.43811e-01   1.02655e-04  -4.34632e-03
#    2  LandauMPV    2.03071e+01   1.50186e-01   1.83373e-04   1.48371e-03
#    3  Normalisation   4.75525e+03   8.42086e+02   1.31327e-01   3.16141e-06
#    4  GaussianSigma   2.13285e+00   3.83576e-01   6.57973e-05   5.89110e-03
#                                ERR DEF= 0.5

# %% [markdown]
# # 2. Fit Sensor 2

# %%
runMng = {
    "u"  :[50,100,150,200,250,300,350,400,500,600,800],               
    "run":["225","226","228","229","230","231","237","238","239","240","241"],
    "uTCACh0_fitRange":[(12,40),(20,60),(30,60),(30,70),(40,90),(40,90),(50,90),(50,90),(50,90),(55,110),(55,110)],
    "uTCACh1_fitRange":[( 8,20),(12,50),(20,50),(20,60),(24,70),(30,70),(30,80),(30,80),(30,90),(30, 90),(30, 90)],
    "VMECh0_fitRange" :[(-1,-1),(10,40),(15,40),(15,50),(20,60),(25,60),(25,60),(25,60),(25,60),(25, 60),(25, 60)],
    "VMECh1_fitRange" :[(-1,-1),( 5,20),( 8,30),(10,30),(10,40),(15,40),(15,40),(15,40),(15,40),(15, 40),(15, 40)],
    "uTCACh0_mpv":[],"uTCACh1_mpv":[],"VMECh0_mpv":[],"VMECh1_mpv":[],
    }
                
for i in range(len(runMng["run"])):
    run = runMng["run"][i]
    df = pd.read_pickle(dataDir + "/TBTree/{}.pkl".format(run))
    for backend in ["uTCA","VME"]:
        for channel in "01":
            # get channe;
            key = "{}Ch{}".format(backend,channel)
            ch = df.query("{}_pulsePosPassCuts>0 & {}_pulseAmpPassCuts>0".format(key,key))
            title = "Run {}, sensor-2 {}V, {}, n={}".format(run,runMng["run"][i], key, len(ch))
            # fitting
            xmin,xmax = runMng[key+"_fitRange"][i]
            fitter = PulseAmpFitter(ch[key+"_pulseAmp"],binsize=1)
            fitter.fitRange(xmin,xmax, None, True)
            runMng[key+"_mpv"].append(fitter.param["argmax"])
            # plot
            fitter.plot()
            fitter.axes[0].set_title(title, fontsize=14)
            plt.savefig("../plots/fitPulseAmp/sensor2/run{}_{}.png".format(run,key),dpi=300)
            plt.close()
            # make heatmap
            chplot = ch.query("{}_pulseAmp>{} and nTriples==1".format(key,xmin))
            plt.figure(figsize=(6,3.5),facecolor='w')
            x = np.array([chplot.tposX_dut]).reshape(-1)
            y = np.array([chplot.tposY_dut]).reshape(-1)
            xBins,yBins = np.arange(-4,3.1,0.1),np.arange(-1,3.1,0.1)
            plt.hist2d(x,y,bins=(xBins,yBins),cmap="hot")
            plt.xlabel("x [mm]",fontsize=14)
            plt.ylabel("y [mm]",fontsize=14)
            plt.axis('equal')
            plt.xlim(-4,3)
            plt.ylim(-1,3)
            title = "Run {}, sensor-2 {}V, {}, n={}".format(run, runMng["run"][i], key, len(chplot))
            plt.title(title, fontsize=14)
            plt.savefig("../plots/heatmap/sensor2/run{}_{}.png".format(run,key),dpi=300)
            plt.close()

pd.DataFrame(runMng).to_pickle(dataDir + "/FitPulseAmp/sensor2.pkl")
