# %%
import pandas as pd
from pylab import *
from BrilReader import *
from BrilPlotter import *

# %matplotlib inline

# %%
col = ['runnum','lsnum','nbnum','bx']
df = BrilReader('../data/example.h5','bcm1futca_lumi_100_1', col)

# %%
plotBunchCrossingHistogram(df.loc[0],binsize=12)
